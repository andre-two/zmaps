# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import geopandas as gpd

# %%
import os

os.getcwd()
# Out:
# '/Users/andre/andre-two/talks-in-maths/zmaps-app/notebooks'

# %%
def read_map(file):
    return gpd.read_file(file)

# %% [markdown]
# # preparando dados para simular

# %%
sp = read_map('../data/SP_setores_CD2022.gpkg')

# %%
# sp_pre = read_map('../data/SP_Malha_Preliminar_2022.gpkg')

# %%
sp1 = read_map('../data/SP_setores_CD2022 (1).gpkg')

# %%
# print(sp.shape, sp_pre.shape, sp1.shape)
# Out:
# (103620, 30) (102718, 23) (103620, 37)

# %%
sp1
# Out:
#                CD_SETOR SITUACAO CD_SIT CD_TIPO   AREA_KM2 CD_REGIAO  \
# 0       350010505000001   Urbana      1       0   0.123824         3
# 1       350010505000002   Urbana      1       0   0.202614         3
# 2       350010505000003   Urbana      1       0   0.235048         3
# 3       350010505000004   Urbana      1       0   0.288468         3
# 4       350010505000005   Urbana      1       0   0.213724         3
# ...                 ...      ...    ...     ...        ...       ...
# 103615  355730305000049   Urbana      2       4   0.159413         3
# 103616  355730305000050   Urbana      2       0   0.090095         3
# 103617  355730305000051    Rural      8       0  36.936974         3
# 103618  355730305000052   Urbana      2       0   1.341469         3
# 103619  355730305000053    Rural      8       0  29.797910         3
#
#        NM_REGIAO CD_UF      NM_UF   CD_MUN  ... CD_CONCURB  \
# 0        Sudeste    35  São Paulo  3500105  ...          .
# ...

# %%
sp1[['CD_SETOR', 'CD_MUN', 'geometry', 'v0001']].to_parquet('../data/geometria/geometrias.parquet')
# Out:
# /opt/anaconda3/envs/mapas/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: this is an initial implementation of Parquet/Feather file support and associated metadata.  This is tracking version 0.1.0 of the metadata specification at https://github.com/geopandas/geo-arrow-spec
#
# This metadata specification does not yet make stability promises.  We do not yet recommend using this in a production setting unless you are able to rewrite your Parquet/Feather files.
#
# To further ignore this warning, you can do:
# import warnings; warnings.filterwarnings('ignore', message='.*initial implementation of Parquet.*')
#   """Entry point for launching an IPython kernel.

# %%
geometria = gpd.read_parquet('../data/geometria/SP_setores_CD2022.parquet')

# %%
sp1.columns
# Out:
# Index(['CD_SETOR', 'SITUACAO', 'CD_SIT', 'CD_TIPO', 'AREA_KM2', 'CD_REGIAO',
#        'NM_REGIAO', 'CD_UF', 'NM_UF', 'CD_MUN', 'NM_MUN', 'CD_DIST', 'NM_DIST',
#        'CD_SUBDIST', 'NM_SUBDIST', 'CD_BAIRRO', 'NM_BAIRRO', 'CD_NU', 'NM_NU',
#        'CD_FCU', 'NM_FCU', 'CD_AGLOM', 'NM_AGLOM', 'CD_RGINT', 'NM_RGINT',
#        'CD_RGI', 'NM_RGI', 'CD_CONCURB', 'NM_CONCURB', 'v0001', 'v0002',
#        'v0003', 'v0004', 'v0005', 'v0006', 'v0007', 'geometry'],
#       dtype='object')

# %%
pd.DataFrame(sp1[['CD_SETOR', 'v0001']]).rename(columns={'v0001': 'populacao'}).to_parquet('../data/agregados_por_geometria/populacao.parquet')

# %%
sp1[['CD_SETOR', 'v0001' ]]
# Out:
#                CD_SETOR  v0001
# 0       350010505000001    288
# 1       350010505000002    674
# 2       350010505000003    380
# 3       350010505000004    570
# 4       350010505000005    612
# ...                 ...    ...
# 103615  355730305000049      0
# 103616  355730305000050    654
# 103617  355730305000051    270
# 103618  355730305000052    386
# 103619  355730305000053    558
#
# [103620 rows x 2 columns]

# %%
pd.DataFrame(sp1[['CD_SETOR', 'v0002']]).rename(columns={'v0002': 'domicilios'}).to_parquet('../data/agregados_por_geometria/domicilios.parquet')

# %% [markdown]
# # dados prontos

# %%
df = gpd.read_parquet('./../data/geometria/geometrias.parquet')

# %%
df = gpd.read_parquet('../data/gdf_novos_por_regiao.parquet')

# %%
df['municipio'] = df['cd_RegiaoRisco'].astype(str).str[:7]
df['uf'] = df['cd_RegiaoRisco'].astype(str).str[:2]
df['macrorregiao'] = df['cd_RegiaoRisco'].astype(str).str[:1]

# %%
df
# Out:
#      cd_RegiaoRisco                                           geometry  \
# 0            520003  POLYGON ((-49.69684 -16.47110, -49.69683 -16.4...
# 1            520006  POLYGON ((-48.11047 -17.44460, -48.11102 -17.4...
# 2            520008  POLYGON ((-48.57355 -18.32787, -48.58237 -18.3...
# 3            520009  POLYGON ((-49.73681 -17.74487, -49.73701 -17.7...
# 4           5200100  POLYGON ((-48.66064 -16.50555, -48.66071 -16.5...
# ...             ...                                                ...
# 2165   150140200013  POLYGON ((-48.48114 -1.44054, -48.48171 -1.441...
# 2166    15014020030  POLYGON ((-48.51032 -1.46136, -48.51043 -1.460...
# 2167   150140200320  POLYGON ((-48.52764 -1.37489, -48.52776 -1.374...
# 2168    15014020110  POLYGON ((-48.60624 -1.23590, -48.60693 -1.235...
# 2169      150140202  POLYGON ((-48.51068 -1.51916, -48.51080 -1.518...
#
#       n_efetivadas  n_calculos  premio_calculado  premio_efetivado        hr  \
# ...

# %%
import folium

# %%
folium.Map(location=[-12.243439, -50.892913], zoom_start=4, tiles='cartodbpositron').save('../map_start.html')

# %%
# Out:
# Running cells with 'zmaps (Python 3.7.12)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n zmaps ipykernel --update-deps --force-reinstall'

# %%
import branca.colormap as cm
color_mapa=cm.linear.RdBu_03.scale(1,10)
color_mapa
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#ef8a62ff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#ef8a62ff;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#f08b63ff;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#f08b64ff;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#f08c64ff;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#f08c65ff;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#f08d65ff;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#f08d66ff;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#f08e67ff;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#f08e67ff;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#f08e68ff;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#f08f68ff;stroke-width:3;" /><line x1="12" y1="0" x2="12" 
# ...

# %%
color_mapa=cm.linear.RdBu_04.scale(1,10)
color_mapa
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#ca0020ff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#cb0020ff;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#cb0121ff;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#cb0221ff;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#cb0322ff;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#cc0423ff;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#cc0523ff;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#cc0624ff;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#cc0724ff;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#cd0825ff;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#cd0926ff;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#cd0a26ff;stroke-width:3;" /><line x1="12" y1="0" x2="12" 
# ...

# %%
color_mapa=cm.linear.RdBu_05.scale(1,10)
color_mapa
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#ca0020ff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#cb0120ff;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#cb0221ff;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#cb0322ff;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#cc0523ff;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#cc0624ff;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#cc0724ff;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#cd0925ff;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#cd0a26ff;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#cd0b27ff;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#ce0d28ff;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#ce0e28ff;stroke-width:3;" /><line x1="12" y1="0" x2="12" 
# ...

# %%
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#b2182bff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#b3192bff;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#b31a2cff;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#b41b2cff;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#b51c2dff;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#b51d2dff;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#b61e2eff;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#b6202fff;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#b7212fff;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#b82230ff;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#b82330ff;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#b92431ff;stroke-width:3;" /><line x1="12" y1="0" x2="12" 
# ...

# %%
color_mapa=cm.linear.RdBu_07.scale(1,10)
color_mapa
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#b2182bff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#b3192bff;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#b41a2cff;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#b41c2dff;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#b51d2dff;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#b61e2eff;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#b7202fff;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#b7212fff;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#b82330ff;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#b92431ff;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#ba2531ff;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#ba2732ff;stroke-width:3;" /><line x1="12" y1="0" x2="12" 
# ...

# %%
color_mapa=cm.linear.RdBu_08.scale(1,10)
color_mapa
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#b2182bff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#b3192bff;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#b31a2cff;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#b41b2cff;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#b41c2dff;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#b51d2dff;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#b51e2eff;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#b61f2eff;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#b6202eff;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#b7212fff;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#b7222fff;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#b82330ff;stroke-width:3;" /><line x1="12" y1="0" x2="12" 
# ...

# %%
color_mapa=cm.linear.RdBu_09.scale(1,10)
color_mapa
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#b2182bff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#b3192bff;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#b31a2cff;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#b41b2cff;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#b51c2dff;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#b51d2dff;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#b61f2eff;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#b6202eff;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#b7212fff;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#b72230ff;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#b82330ff;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#b92431ff;stroke-width:3;" /><line x1="12" y1="0" x2="12" 
# ...

# %%
color_mapa=cm.linear.RdBu_10.scale(1,10)
color_mapa
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#67001fff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#68001fff;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#6a001fff;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#6b011fff;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#6c011fff;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#6e0220ff;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#6f0220ff;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#700320ff;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#720320ff;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#730321ff;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#740421ff;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#760421ff;stroke-width:3;" /><line x1="12" y1="0" x2="12" 
# ...

# %%
color_mapa=cm.linear.RdBu_11.scale(1,10)
color_mapa
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#67001fff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#68001fff;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#6a001fff;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#6b011fff;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#6d0120ff;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#6e0220ff;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#700220ff;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#710320ff;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#730321ff;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#740421ff;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#760421ff;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#780521ff;stroke-width:3;" /><line x1="12" y1="0" x2="12" 
# ...

# %%
color_mapa=cm.linear.RdBu_06.scale(1,10)
color_mapa
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#b2182bff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#b3192bff;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#b31a2cff;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#b41b2cff;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#b51c2dff;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#b51d2dff;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#b61e2eff;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#b6202fff;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#b7212fff;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#b82230ff;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#b82330ff;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#b92431ff;stroke-width:3;" /><line x1="12" y1="0" x2="12" 
# ...

# %%
color_mapa.colors
# Out:
# [(0.6980392156862745, 0.09411764705882353, 0.16862745098039217, 1.0),
#  (0.9372549019607843, 0.5411764705882353, 0.3843137254901961, 1.0),
#  (0.9921568627450981, 0.8588235294117647, 0.7803921568627451, 1.0),
#  (0.8196078431372549, 0.8980392156862745, 0.9411764705882353, 1.0),
#  (0.403921568627451, 0.6627450980392157, 0.8117647058823529, 1.0),
#  (0.12941176470588237, 0.4, 0.6745098039215687, 1.0)]

# %%
color_mapa.index
# Out:
# [1.0, 2.8, 4.6, 6.3999999999999995, 8.2, 10.0]

# %%
color_mapa
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#b2182bff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#b3192bff;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#b31a2cff;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#b41b2cff;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#b51c2dff;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#b51d2dff;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#b61e2eff;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#b6202fff;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#b7212fff;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#b82230ff;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#b82330ff;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#b92431ff;stroke-width:3;" /><line x1="12" y1="0" x2="12" 
# ...

# %%
color_mapa = cm.LinearColormap(
    [(0.09411764705882353, 0.09411764705882353, 0.09411764705882353, 1.0),
     (0.6980392156862745, 0.09411764705882353, 0.16862745098039217, 1.0),
     (0.9372549019607843, 0.5411764705882353, 0.3843137254901961, 1.0),
     (0.9921568627450981, 0.8588235294117647, 0.7803921568627451, 1.0),
    #  (0.8196078431372549, 0.8980392156862745, 0.9411764705882353, 1.0),
     (0.403921568627451, 0.6627450980392157, 0.8117647058823529, 1.0),
     (0.12941176470588237, 0.4, 0.6745098039215687, 1.0)], 

    # [0., 0.2, 0.45, 0.55, 0.7, 1.],
    [0., 0.01, 0.4, .5, 0.6, 1.],
    )

# %%
color_mapa = color_mapa.scale(0, 10)

# %%
color_mapa
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#181818ff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#37181bff;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#56181fff;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#751823ff;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#941827ff;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#b2182bff;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#b3182bff;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#b3192bff;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#b3192cff;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#b31a2cff;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#b41b2cff;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#b41b2cff;stroke-width:3;" /><line x1="12" y1="0" x2="12" 
# ...

# %%
cm.LinearColormap(
                [(0.6980392156862745, 0.09411764705882353, 0.16862745098039217, 1.0),
                # (0.9372549019607843, 0.5411764705882353, 0.3843137254901961, 1.0),
                # (0.9921568627450981, 0.8588235294117647, 0.7803921568627451, 1.0),
                (0.8196078431372549, 0.8980392156862745, 0.9411764705882353, 1.0),
                # (0.403921568627451, 0.6627450980392157, 0.8117647058823529, 1.0),
                (0.12941176470588237, 0.4, 0.6745098039215687, 1.0)], 

                # [0., 0.2, 0.49, 0.51, 0.7, 1.],
                # [0., 0.49, 0.51, 1.],
                [0., 0.5, 1.],
                )
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#b2182bff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#b2182bff;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#b2192cff;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#b31a2dff;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#b31b2eff;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#b31c2fff;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#b31d2fff;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#b31d30ff;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#b31e31ff;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#b31f32ff;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#b32033ff;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#b42133ff;stroke-width:3;" /><line x1="12" y1="0" x2="12" 
# ...

# %%
import branca.colormap as cm

cm.LinearColormap(
    [(0.6980392156862745, 0.09411764705882353, 0.16862745098039217, 1.0),
     (0.9372549019607843, 0.5411764705882353, 0.3843137254901961, 1.0),
    #  (0.9921568627450981, 0.8588235294117647, 0.7803921568627451, 1.0),
    #  (0.8196078431372549, 0.8980392156862745, 0.9411764705882353, 1.0),
     (0.403921568627451, 0.6627450980392157, 0.8117647058823529, 1.0),
     (0.12941176470588237, 0.4, 0.6745098039215687, 1.0)], 

    [0., 0.3, 0.6, 1.],
    max_labels = 0
    )
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#b2182bff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#b3182bff;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#b3192bff;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#b31a2cff;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#b41b2cff;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#b41b2dff;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#b51c2dff;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#b51d2dff;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#b51e2eff;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#b61e2eff;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#b61f2eff;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#b7202fff;stroke-width:3;" /><line x1="12" y1="0" x2="12" 
# ...

# %%
indices = [0, 0.2, 0.3, 0.5, 0.7, 0.8, 4.]

# %%
q0, q10 = indices[0], indices[-1]
n0, n2, n3, n5, n7, n8, n10 = [(j - q0)/(q10 - q0) for j in indices]

# %%
n0, n2, n3, n5, n7, n8, n10 = indices

# %%
print(n0, n2, n3, n5, n7, n8, n10)
# Out:
# 0.0 0.05 0.075 0.125 0.175 0.2 1.0

# %%
cm.LinearColormap(
                [(0.6980392156862745, 0.09411764705882353, 0.16862745098039217, 1.0),
                (0.9372549019607843, 0.5411764705882353, 0.3843137254901961, 1.0),
                (0.9921568627450981, 0.8588235294117647, 0.7803921568627451, 1.0),
                # (0.8196078431372549, 0.8980392156862745, 0.9411764705882353, 1.0),
                (0.403921568627451, 0.6627450980392157, 0.8117647058823529, 1.0),
                (0.12941176470588237, 0.4, 0.6745098039215687, 1.0)], 

                # [0., 0.2, 0.5,  0.7, 1.],
                [n0, n2, n5, n7, n10],
                # [0., 0.2, 0.5,  0.7, 1.],
                max_labels = 0
                ).scale(q0, q10)
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#b2182bff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#b51c2dff;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#b7212fff;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#ba2531ff;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#bc2a34ff;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#be2f36ff;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#c13338ff;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#c3383aff;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#c63c3cff;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#c8413fff;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#cb4541ff;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#cd4a43ff;stroke-width:3;" /><line x1="12" y1="0" x2="12" 
# ...

# %%
import pandas as pd
pd.read_parquet('../data/gdf_novos_por_regiao.parquet')
# Out:
#      cd_RegiaoRisco                                           geometry  \
# 0            520003  b'\x01\x03\x00\x00\x00\x02\x00\x00\x00\xecd\x0...
# 1            520006  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x8b3\x0...
# 2            520008  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\xa42\x0...
# 3            520009  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\xb8B\x0...
# 4           5200100  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00]7\x00\x...
# ...             ...                                                ...
# 2165   150140200013  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00}\x00\x0...
# 2166    15014020030  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\r\x01\x...
# 2167   150140200320  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\xf1\x02...
# 2168    15014020110  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00G\x0b\x0...
# 2169      150140202  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00g\x06\x0...
#
#       n_efetivadas  n_calculos  premio_calculado  premio_efetivado        hr  \
# ...
